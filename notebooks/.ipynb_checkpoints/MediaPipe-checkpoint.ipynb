# %% [markdown]
# # MediaPipe

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pathlib import Path

# %%
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# %%
model_path = Path("..", "models", "pose_landmarker_heavy.task")
image_path = Path("..", "data", "OrangeGuy.jpg")

# %%
image = cv.imread(image_path)
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
detector = vision.PoseLandmarker.create_from_options(
    mp.tasks.vision.PoseLandmarkerOptions(
        base_options = mp.tasks.BaseOptions(
            model_asset_path=model_path
        ),
        running_mode=mp.tasks.vision.RunningMode.IMAGE
    )
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762949743.718542   72263 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1762949743.720748   72356 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.2.6), renderer: Mesa Intel(R) Iris(R) Xe Graphics (RPL-P)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1762949743.763344   72360 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1762949743.831012   72371 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=image)
result = detector.detect(mp_image)
# Out:
# W0000 00:00:1762949857.126996   72360 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.

# %%
print(result.pose_landmarks])
plt.plot(result.pose_landmarks[1:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print(result.pose_landmarks["NormalizedLandmark"])
#       2 plt.plot(result.pose_landmarks[1:])
#
# TypeError: list indices must be integers or slices, not str
